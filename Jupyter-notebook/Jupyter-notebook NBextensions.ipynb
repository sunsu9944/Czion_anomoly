# %% [markdown]
# # Jupyter-Note book 확장 프로그램 설치

# %%
# !pip install jupyter_nbextensions_configurator jupyter_contrib_nbextensions
# !jupyter contrib nbextensions install --user
# !jupyter nbextensions_configurator enable --user
# Out:
# ...
# [I 21:15:53 InstallContribNbextensionsApp] jupyter contrib nbextension install --user
# [I 21:15:53 InstallContribNbextensionsApp] Installing jupyter_contrib_nbextensions nbextension files to jupyter data directory
# [I 21:15:53 InstallContribNbextensionsApp] Installing /home/twogudack/anaconda3/envs/pytorch/lib/python3.6/site-packages/jupyter_contrib_nbextensions/nbextensions/zenmode -> zenmode
# [I 21:15:53 InstallContribNbextensionsApp] Up to date: /home/twogudack/.local/share/jupyter/nbextensions/zenmode/main.css
# [I 21:15:53 InstallContribNbextensionsApp] Up to date: /home/twogudack/.local/share/jupyter/nbextensions/zenmode/README.md
# [I 21:15:53 InstallContribNbextensionsApp] Up to date: /home/twogudack/.local/share/jupyter/nbextensions/zenmode/main.js
# [I 21:15:53 InstallContribNbextensionsApp] Up to date: /home/twogudack/.local/share/jupyter/nbextensions/zenmode/zenmode.yaml
# ...

# %% [markdown]
# ## 설치후 jupyter-notebok 다시 실행 <br>
# ## Nbextensions 생김

# %% [markdown]
# # jupyter 확장 체크 목록.
# ![%EC%8A%A4%ED%81%AC%EB%A6%B0%EC%83%B7,%202022-09-03%2013-05-49.png](attachment:%EC%8A%A4%ED%81%AC%EB%A6%B0%EC%83%B7,%202022-09-03%2013-05-49.png)

# %%
>
